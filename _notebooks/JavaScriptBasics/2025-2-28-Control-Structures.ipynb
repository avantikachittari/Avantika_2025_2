# %%
---
comments: true
layout: post
title: Control Structures
description: In this blog I will talk about working on software development as a team by relating it to our platformer4x game and the adventure game.
permalink: /JavaScriptBasics/2025-2-28-Control-Structures.ipynb/
type: ccc
author: Avantika Chittari
---

# %% [markdown]
# <style>
#     body {
#         background-color: #fce4ec; /* Light pink background */
#         color: #3949ab; /* Deep blue text */
#         font-family: 'Courier New', monospace;
#         line-height: 1.6;
#     }
#     h1, h2, h3 {
#         color: #e91e63; /* Bright pink headers */
#     }
#     code {
#         background-color: #bbdefb; /* Light blue code background */
#         padding: 8px;
#         border-radius: 5px;
#         display: block;
#     }
# </style>
#
# # **Control Structures in Programming**
#
# ## **Iteration (Loops)**
# Loops allow us to repeat a block of code multiple times.
#
# ### **For Loop**
#
# <pre><code>
# for (let i = 0; i < 5; i++) {
#     console.log("Iteration number: " + i);
# }
# </code></pre>

# %% [markdown]
# <style>
#     body {
#         background-color: #fce4ec; /* Light pink background */
#         color: #3949ab; /* Deep blue text */
#         font-family: 'Courier New', monospace;
#         line-height: 1.6;
#     }
#     h1, h2, h3 {
#         color: #e91e63; /* Bright pink headers */
#     }
#     code {
#         background-color: #bbdefb; /* Light blue code background */
#         padding: 8px;
#         border-radius: 5px;
#         display: block;
#     }
# </style>
# ### **While loop**
#
# <pre><code>
# for (let count = 0;
# while (count < 5) {
#     console.log("Count is: " + count);
#     count++;
# }) {
#     console.log("Iteration number: " + i);
# }
# </code></pre>

# %% [markdown]
# <style>
#     body {
#         background-color: #fce4ec; /* Light pink background */
#         color: #3949ab; /* Deep blue text */
#         font-family: 'Courier New', monospace;
#         line-height: 1.6;
#     }
#     h1, h2, h3 {
#         color: #e91e63; /* Bright pink headers */
#     }
#     code {
#         background-color: #bbdefb; /* Light blue code background */
#         padding: 8px;
#         border-radius: 5px;
#         display: block;
#     }
# </style>
# ### **Do-While Loop**
#
# <pre><code>
# let num = 0;
# do {
#     console.log("Number: " + num);
#     num++;
# } while (num < 5);;
# </code></pre>

# %% [markdown]
# <style>
#     body {
#         background-color: #fce4ec; /* Light pink background */
#         color: #3949ab; /* Deep blue text */
#         font-family: 'Courier New', monospace;
#         line-height: 1.6;
#     }
#     h1, h2, h3 {
#         color: #e91e63; /* Bright pink headers */
#     }
#     code {
#         background-color: #bbdefb; /* Light blue code background */
#         padding: 8px;
#         border-radius: 5px;
#         display: block;
#     }
# </style>
#
# ## **Conditional Statements**
# Conditionals control decision-making in a program based on Boolean conditions.
#
# ### **If statement**
#
# <pre><code>
# let age = 18;
# if (age >= 18) {
#     console.log("You are an adult.");
# }
# </code></pre>

# %% [markdown]
# <style>
#     body {
#         background-color: #fce4ec; /* Light pink background */
#         color: #3949ab; /* Deep blue text */
#         font-family: 'Courier New', monospace;
#         line-height: 1.6;
#     }
#     h1, h2, h3 {
#         color: #e91e63; /* Bright pink headers */
#     }
#     code {
#         background-color: #bbdefb; /* Light blue code background */
#         padding: 8px;
#         border-radius: 5px;
#         display: block;
#     }
# </style>
# ### **If Else Statement**
#
# <pre><code>
# let temperature = 30;
# if (temperature > 25) {
#     console.log("It’s hot outside.");
# } else {
#     console.log("It’s cool outside.");
# }
# </code></pre>

# %% [markdown]
# <style>
#     body {
#         background-color: #fce4ec; /* Light pink background */
#         color: #3949ab; /* Deep blue text */
#         font-family: 'Courier New', monospace;
#         line-height: 1.6;
#     }
#     h1, h2, h3 {
#         color: #e91e63; /* Bright pink headers */
#     }
#     code {
#         background-color: #bbdefb; /* Light blue code background */
#         padding: 8px;
#         border-radius: 5px;
#         display: block;
#     }
# </style>
# ### **Else If Ladder**
#
# <pre><code>
# let score = 85;
# if (score >= 90) {
#     console.log("Grade: A");
# } else if (score >= 80) {
#     console.log("Grade: B");
# } else if (score >= 70) {
#     console.log("Grade: C");
# } else {
#     console.log("Grade: F");
# }
# </code></pre>

# %% [markdown]
# <style>
#     body {
#         background-color: #fce4ec; /* Light pink background */
#         color: #3949ab; /* Deep blue text */
#         font-family: 'Courier New', monospace;
#         line-height: 1.6;
#     }
#     h1, h2, h3 {
#         color: #e91e63; /* Bright pink headers */
#     }
#     code {
#         background-color: #bbdefb; /* Light blue code background */
#         padding: 8px;
#         border-radius: 5px;
#         display: block;
#     }
# </style>
#
# ## **Nested Conditionals**
# Nested conditions are when one conditional statement is placed inside another, allowing for more complex decision-making based on multiple conditions.
#
# ### **Nested If statement**
#
# <pre><code>
# let userLoggedIn = true;
# let isAdmin = false;
# if (userLoggedIn) {
#     if (isAdmin) {
#         console.log("Welcome, Admin!");
#     } else {
#         console.log("Welcome, User!");
#     }
# } else {
#     console.log("Please log in.");
# }
# </code></pre>
# ### **Nested Loops**
#
# <pre><code>
# for (let i = 0; i < 3; i++) {
#     for (let j = 0; j < 3; j++) {
#         console.log(`i: ${i}, j: ${j}`);
#     }
# }
# </code></pre>
